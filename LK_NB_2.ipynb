# %% [markdown]
# ## Looking at a different EV dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv('./data/CO_EV_Registrations.csv')
raw_df
# Out:
# /var/folders/d3/3fhlv1gn0k73glsv1lv807fc0000gn/T/ipykernel_70162/3217689266.py:1: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_df = pd.read_csv('./data/CO_EV_Registrations.csv')
#         State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0          CO    81301          3/1/2021        TESLA       MODEL 3
# 1          CO    80112          3/1/2021        TESLA       MODEL 3
# 2          CO    80126          3/1/2021        TESLA       MODEL 3
# 3          CO    80202          3/1/2021        TESLA       MODEL 3
# 4          CO    80013          3/1/2021        TESLA       MODEL 3
# ...       ...      ...               ...          ...           ...
# 2701331    CO    80026          7/1/2023       NISSAN          LEAF
# 2701332    CO    80026         12/1/2021       NISSAN          LEAF
# 2701333    CO    80026          8/1/2021       NISSAN          LEAF
# ...
